# %%
# Author:Akre Acho Jean

# Entrainer un modele de KNN pour predire l'observation de plante avec le dataSet
# iris. Determination du meilleur k pour le modele
# Calcul de l'erreur quadratique rmse
# calcul de la performance du modele en fonction de la valeur de k entre 1 et 25


from sklearn.datasets import load_iris
from sklearn.neighbors._classification import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import  metrics
import matplotlib.pyplot as plt


iris = load_iris()
X= iris.data
y= iris.target

X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.25, random_state = 20)

k_values =[x for x in range(1,25)]
rmse_list = {}
performance_list = {}
for k in k_values:
  knn = KNeighborsClassifier(n_neighbors= k)
  knn.fit(x_train, y_train)
  prediction = knn.predict(x_test)

  rmse = (mean_squared_error(y_test, prediction))**(1/2)
  rmse_list[k] = rmse
  knn_performance = metrics.accuracy_score(y_test, prediction)
  performance_list[k] = knn_performance

print(sorted(rmse_list.items(), key=lambda item: item[1]))

plt.plot(list(performance_list.keys()), list(performance_list.values()))
plt.xlabel('K_values')
plt.ylabel('Performances')
plt.show()
# Out:
# [(7, 0.16222142113076254), (9, 0.16222142113076254), (10, 0.16222142113076254), (11, 0.16222142113076254), (12, 0.16222142113076254), (13, 0.16222142113076254), (14, 0.16222142113076254), (15, 0.16222142113076254), (16, 0.16222142113076254), (17, 0.16222142113076254), (18, 0.16222142113076254), (19, 0.16222142113076254), (20, 0.16222142113076254), (21, 0.16222142113076254), (5, 0.22941573387056177), (6, 0.22941573387056177), (8, 0.22941573387056177), (22, 0.22941573387056177), (23, 0.22941573387056177), (24, 0.22941573387056177), (3, 0.28097574347450816), (4, 0.28097574347450816), (1, 0.3244428422615251), (2, 0.3244428422615251)]

# %%
#Determiner la performance de la prediction par categorie des plantes observees
# Iris-Setosa

# Iris-Versicolore

# Iris-Virginica
# Modele de Regression logistique
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(solver='liblinear')
lr.fit(x_train, y_train)
predictions = lr.predict(x_test)
log_performance = metrics.accuracy_score(y_test, predictions)

print(log_performance)
# Out:
# 0.9210526315789473
